# %%
import sys
import numpy as np
import matplotlib.pyplot as plt

# %%
filename = '../cache/str_parallel/checkpoints/loss_history_001.txt'
losses = np.loadtxt(filename)

plt.plot(losses)
plt.xlabel('iterations')
plt.ylabel('loss')
plt.show()
