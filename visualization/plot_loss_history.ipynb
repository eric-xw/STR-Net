# %%
import sys
import numpy as np
import matplotlib.pyplot as plt

# %%
filename = '../cache/LR_0.0001_without_decay/checkpoints/loss_history_004.txt'
losses = np.loadtxt(filename)

plt.plot(losses)
plt.xlabel('iterations')
plt.ylabel('loss')
plt.show()
