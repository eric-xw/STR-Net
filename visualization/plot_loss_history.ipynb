# %%
import sys
import numpy as np
import matplotlib.pyplot as plt

# %%
filename = '../cache/debug/checkpoints/loss_history_003.txt'
losses = np.loadtxt(filename)

plt.plot(losses)
plt.xlabel('iterations')
plt.ylabel('loss')
plt.show()
